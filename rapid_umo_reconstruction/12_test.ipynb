# %%
import tensorboard

# %%
# !tensorboard --logdir=../rapid-geostrophic-reconstruction/runs --bind_all
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.12.1 at http://nesh-srp339:6006/ (Press CTRL+C to quit)

# %%
import xarray as xr

# %%
time_mapping_dict_90D = None 
import pickle
with open('../rapid-geostrophic-reconstruction/datasets/smoothing_90_days/argo_after_2012/base_sample/time_mapping_dict_1st_70None.pickle', 'rb') as f:
    time_mapping_dict_90D = pickle.load(f)


time_mapping_dict_10D = None
with open('../rapid-geostrophic-reconstruction/datasets/smoothing_10_days/argo_after_2012/base_sample/time_mapping_dict_1st_70None.pickle', 'rb') as f:
    time_mapping_dict_10D = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 9
#       7 time_mapping_dict_10D = None
#       8 with open('../rapid-geostrophic-reconstruction/datasets/smoothing_10_days/argo_after_2012/base_sample/time_mapping_dict_1st_70None.pickle', 'rb') as f:
# ----> 9     time_mapping_dict_10D = pickle.load(f)
#
# EOFError: Ran out of input

# %%
time_mapping_dict_90D.keys()
# Out:
# dict_keys([numpy.datetime64('1957-12-05T00:00:00.000000000'), numpy.datetime64('1958-03-05T00:00:00.000000000'), numpy.datetime64('1958-06-03T00:00:00.000000000'), numpy.datetime64('1958-09-01T00:00:00.000000000'), numpy.datetime64('1958-11-30T00:00:00.000000000'), numpy.datetime64('1959-02-28T00:00:00.000000000'), numpy.datetime64('1959-05-29T00:00:00.000000000'), numpy.datetime64('1959-08-27T00:00:00.000000000'), numpy.datetime64('1959-11-25T00:00:00.000000000'), numpy.datetime64('1960-02-23T00:00:00.000000000'), numpy.datetime64('1960-05-23T00:00:00.000000000'), numpy.datetime64('1960-08-21T00:00:00.000000000'), numpy.datetime64('1960-11-19T00:00:00.000000000'), numpy.datetime64('1961-02-17T00:00:00.000000000'), numpy.datetime64('1961-05-18T00:00:00.000000000'), numpy.datetime64('1961-08-16T00:00:00.000000000'), numpy.datetime64('1961-11-14T00:00:00.000000000'), numpy.datetime64('1962-02-12T00:00:00.000000000'), numpy.datetime64('1962-05-13T00:00:00.000000000'), numpy.datetime64('
# ...
